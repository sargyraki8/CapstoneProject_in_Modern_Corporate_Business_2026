# %% [markdown]
# # rep_revenue_per_customer_and_period
#
# Runs the corresponding reporting script to create or refresh the `rep_revenue_per_customer_and_period` table in BigQuery.

# %%
from pathlib import Path
import runpy

candidate_paths = [Path.cwd(), *Path.cwd().parents]
repo_root = next((path for path in candidate_paths if (path / "scripts").exists()), None)
if repo_root is None:
    raise FileNotFoundError("Could not locate the repository root containing the scripts directory.")
script_path = repo_root / "scripts" / "reporting" / "rep_revenue_per_customer_and_period.py"
runpy.run_path(str(script_path), run_name="__main__")
